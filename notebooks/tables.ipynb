# %% [markdown]
# # Caution
#
# This is a supporting/appendix notebook. Some tables may come from historical runs with older triple-barrier or exposure assumptions. Verify the labeler, DGP calibration, and portfolio construction before citing a table as a current result.

# %% [markdown]
# ## Tables

# %% [markdown]
# ### Table A: Triple Barrier Horizon Check
#
# | Horizon | Total Labels | Label 1 | Label 0 | Label 1 Rate | Long Label 1 Rate | Short Label 1 Rate |
# |--------:|-------------:|--------:|--------:|-------------:|------------------:|-------------------:|
# | 15  | 4862500 | 1240950 | 3621550 | 0.2552 | 0.2793 | 0.2311 |
# | 25  | 4857500 | 1255861 | 3601639 | 0.2585 | 0.2952 | 0.2218 |
# | 35  | 4852500 | 1240052 | 3612448 | 0.2555 | 0.3043 | 0.2067 |
# | 45  | 4847500 | 1214966 | 3632534 | 0.2506 | 0.3105 | 0.1906 |
# | 55  | 4842500 | 1184099 | 3658401 | 0.2445 | 0.3144 | 0.1743 |
# | 65  | 4837500 | 1150057 | 3687443 | 0.2377 | 0.3168 | 0.1584 |
# | 75  | 4832500 | 1118760 | 3713740 | 0.2315 | 0.3187 | 0.1440 |
# | 85  | 4827500 | 1089825 | 3737675 | 0.2258 | 0.3206 | 0.1306 |
# | 95  | 4822500 | 1064608 | 3757892 | 0.2208 | 0.3222 | 0.1189 |
# | 105 | 4817500 | 1042837 | 3774663 | 0.2165 | 0.3236 | 0.1090 |

# %% [markdown]
# ### Table B: Secondary model performance check based on triple barrier horizon
#
# *Note: for the secondary model, a simpler strategy has been used, namely only including "zscore", "ret_5", "ret_20", "ret_60", "vol_20". A sanity check has been done with the current setup where 30 day vertical barrier horizon has been compared with 120 day horizon, and can be seen at table D*
#
# | Horizon | Label 1 Rate | Long Label 1 Rate | Short Label 1 Rate | Prob. Mean | Prob. Std | Max Prob. | Pred. Positive Rate (0.5) | Accuracy (0.5) | ROC AUC |
# |--------:|-------------:|------------------:|-------------------:|-----------:|----------:|----------:|--------------------------:|---------------:|--------:|
# | 15  | 0.2572 | 0.2802 | 0.2343 | 0.2579 | 0.0426 | 0.4220 | 0.0000 | 0.7442 | 0.5612 |
# | 30  | 0.2599 | 0.3012 | 0.2188 | 0.2610 | 0.0599 | 0.5154 | 0.0000 | 0.7424 | 0.5849 |
# | 60  | 0.2442 | 0.3173 | 0.1713 | 0.2455 | 0.0901 | 0.6699 | 0.0085 | 0.7571 | 0.6356 |
# | 120 | 0.2123 | 0.3257 | 0.0992 | 0.2135 | 0.1201 | 0.8256 | 0.0288 | 0.7859 | 0.7044 |
# | 150 | 0.2029 | 0.3269 | 0.0793 | 0.2041 | 0.1261 | 0.8553 | 0.0323 | 0.7950 | 0.7242 |

# %% [markdown]
# ### Table C: Secondary model based on feature selection and parameter changing
#
# | Specification | Threshold | ROC AUC | Accuracy | Precision (Class 1) | Recall (Class 1) | Prob. Mean | Prob. Std | Max Prob. | Pred. Positive Rate |
# |---|---:|---:|---:|---:|---:|---:|---:|---:|---:|
# | Original baseline | 0.5 | 0.5950 | 0.74 | 0.50 | 0.00 | 0.2584 | 0.0606 | 0.5315 | 0.00007 |
# | Risk-adjusted returns + weight | 0.5 | 0.5585 | 0.74 | 0.00 | 0.00 | 0.2582 | 0.0339 | 0.4400 | 0.00000 |
# | Risk-adjusted returns + weight + vol\_20 | 0.5 | 0.5950 | 0.74 | 0.57 | 0.00 | 0.2583 | 0.0606 | 0.5279 | 0.00006 |
# | Risk-adjusted returns + weight + vol\_20 + raw returns | 0.5 | 0.5943 | 0.74 | 0.00 | 0.00 | 0.2582 | 0.0608 | 0.5290 | 0.00000 |
# | Raw returns + weight + vol\_20 + vol\_60 + vol\_150 | 0.5 | 0.6186 | 0.57 | 0.33 | 0.61 | 0.4897 | 0.1054 | 0.8741 | 0.48795 |
# | Raw returns + weight + vol\_20 + vol\_60 + vol\_150 | 0.6 | 0.6186 | 0.70 | 0.38 | 0.21 | 0.4897 | 0.1054 | 0.8741 | 0.14499 |

# %% [markdown]
# ### Table D: Comparing last result with 150 days horizon for the triple barrier
#
# | Triple-Barrier Horizon | Threshold | ROC AUC | Accuracy | Precision (Class 1) | Recall (Class 1) | Prob. Mean | Prob. Std | Max Prob. | Pred. Positive Rate |
# |---|---:|---:|---:|---:|---:|---:|---:|---:|---:|
# | 30 days | 0.6 | 0.6186 | 0.70 | 0.38 | 0.21 | 0.4897 | 0.1054 | 0.8741 | 0.14499 |
# | 150 days | 0.6 | 0.7326 | 0.73 | 0.37 | 0.46 | 0.4521 | 0.2018 | 0.9815 | 0.25668 |
